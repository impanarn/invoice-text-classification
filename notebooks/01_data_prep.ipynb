# %%
BASE_PATH = r"C:\Users\Impana\Downloads\invoice-classification\\"

# %%
import pandas as pd
import os

raw_path = os.path.join(BASE_PATH, "data", "raw", "Dataset", "Train.csv")
df_raw = pd.read_csv(raw_path)

df = df_raw[['Item_Description', 'Product_Category']].dropna()
df.columns = ['description', 'label']

out_path = os.path.join(BASE_PATH, "data", "D01_raw.csv")
df.to_csv(out_path, index=False)
print("Saved:", out_path, len(df), "rows")
# Out:
# Saved: C:\Users\Impana\Downloads\invoice-classification\\data\D01_raw.csv 5566 rows
